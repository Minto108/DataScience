# %%
import yfinance as yf
import pandas as pd

# %%
kitex = yf.Ticker('KITEX.NS')

# %%
kitex.info
# Out:
# {'address1': 'Building No. VI/496',
#  'address2': 'Kizhakkambalam Vilangu P.O, Aluva',
#  'city': 'Ernakulam',
#  'zip': '683561',
#  'country': 'India',
#  'phone': '91 48 4258 5000',
#  'fax': '91 48 4268 0604',
#  'website': 'https://www.kitexgarments.com',
#  'industry': 'Apparel Manufacturing',
#  'industryKey': 'apparel-manufacturing',
#  'industryDisp': 'Apparel Manufacturing',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
#  'longBusinessSummary': 'Kitex Garments Limited manufactures and sells fabric and readymade garments for infants and children in India, the United States, and internationally. It manufactures and exports knitted fabrics and infant garments. The company sells baby suits, sleepwear, rompers, burps, bips, and training pants. It exports its products. Kitex Garments Limited was incorporated in 1992 and is headquartered in Ernakulam, India.',
#  'fullTimeEmployees': 5258,
# ...

# %%
kitex.history(period = 'max')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2012-09-25 00:00:00+05:30   13.561351   14.468320   13.388595   13.528959
# 2012-09-26 00:00:00+05:30   15.116156   15.116156   12.956706   13.442582
# 2012-09-27 00:00:00+05:30   13.755702   13.777297   13.064678   13.215839
# 2012-09-28 00:00:00+05:30   12.956705   13.345405   12.578801   12.913516
# 2012-10-01 00:00:00+05:30   13.129461   13.906864   11.876980   12.675977
# ...                               ...         ...         ...         ...
# 2025-09-23 00:00:00+05:30  214.350006  217.500000  202.500000  206.809998
# 2025-09-24 00:00:00+05:30  206.850006  211.789993  205.089996  207.350006
# 2025-09-25 00:00:00+05:30  207.990005  210.199997  198.210007  199.589996
# 2025-09-26 00:00:00+05:30  201.800003  201.800003  189.610001  190.979996
# 2025-09-30 00:00:00+05:30  187.509995  190.419998  185.020004  186.649994
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
kitex.calendar
# Out:
# {'Ex-Dividend Date': datetime.date(2025, 9, 10),
#  'Earnings Date': [datetime.date(2025, 8, 12), datetime.date(2025, 8, 16)],
#  'Earnings High': None,
#  'Earnings Low': None,
#  'Earnings Average': None,
#  'Revenue High': None,
#  'Revenue Low': None,
#  'Revenue Average': None}

# %%
kitex.analyst_price_targets
# Out:
# {'current': 186.65}

# %%
kitex.quarterly_income_stmt
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  3.154020e-01
# Normalized EBITDA                                   3.491280e+08
# Net Income From Continuing Operation Net Minori...  2.076120e+08
# Reconciled Depreciation                             3.173800e+07
# Reconciled Cost Of Revenue                          8.915470e+08
# EBITDA                                              3.491280e+08
# EBIT                                                3.173900e+08
# Net Interest Income                                -3.542300e+07
# Interest Expense                                    3.542300e+07
# Normalized Income                                   2.076120e+08
# Net Income From Continuing And Discontinued Ope...  2.076120e+08
# Total Expenses                                      1.656777e+09
# ...

# %%
kit = kitex.history(period='max')
kit
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2012-09-25 00:00:00+05:30   13.561352   14.468321   13.388596   13.528960
# 2012-09-26 00:00:00+05:30   15.116156   15.116156   12.956706   13.442582
# 2012-09-27 00:00:00+05:30   13.755703   13.777298   13.064678   13.215840
# 2012-09-28 00:00:00+05:30   12.956706   13.345406   12.578802   12.913517
# 2012-10-01 00:00:00+05:30   13.129459   13.906862   11.876979   12.675975
# ...                               ...         ...         ...         ...
# 2025-09-23 00:00:00+05:30  214.350006  217.500000  202.500000  206.809998
# 2025-09-24 00:00:00+05:30  206.850006  211.789993  205.089996  207.350006
# 2025-09-25 00:00:00+05:30  207.990005  210.199997  198.210007  199.589996
# 2025-09-26 00:00:00+05:30  201.800003  201.800003  189.610001  190.979996
# 2025-09-30 00:00:00+05:30  187.509995  190.419998  185.020004  186.649994
#
#                             Volume  Dividends  Stock Splits
# Date
# ...

# %%
kit.reset_index(inplace=True)

# %%
kit
# Out:
#                           Date        Open        High         Low  \
# 0    2012-09-25 00:00:00+05:30   13.561352   14.468321   13.388596
# 1    2012-09-26 00:00:00+05:30   15.116156   15.116156   12.956706
# 2    2012-09-27 00:00:00+05:30   13.755703   13.777298   13.064678
# 3    2012-09-28 00:00:00+05:30   12.956706   13.345406   12.578802
# 4    2012-10-01 00:00:00+05:30   13.129459   13.906862   11.876979
# ...                        ...         ...         ...         ...
# 3204 2025-09-23 00:00:00+05:30  214.350006  217.500000  202.500000
# 3205 2025-09-24 00:00:00+05:30  206.850006  211.789993  205.089996
# 3206 2025-09-25 00:00:00+05:30  207.990005  210.199997  198.210007
# 3207 2025-09-26 00:00:00+05:30  201.800003  201.800003  189.610001
# 3208 2025-09-30 00:00:00+05:30  187.509995  190.419998  185.020004
#
#            Close   Volume  Dividends  Stock Splits
# 0      13.528960   250488        0.0           0.0
# 1      13.442582   154056        0.0           0.0
# ...

# %%
kitex.dividends
# Out:
# Date
# 2013-05-07 00:00:00+05:30    0.190476
# 2014-05-07 00:00:00+05:30    0.238095
# 2015-05-25 00:00:00+05:30    0.297619
# 2015-10-29 00:00:00+05:30    0.178571
# 2016-06-02 00:00:00+05:30    0.178571
# 2016-11-17 00:00:00+05:30    0.178571
# 2017-06-09 00:00:00+05:30    0.178571
# 2017-11-16 00:00:00+05:30    0.250000
# 2018-07-19 00:00:00+05:30    0.250000
# 2019-08-19 00:00:00+05:30    0.500000
# 2020-02-18 00:00:00+05:30    0.500000
# 2021-08-30 00:00:00+05:30    0.500000
# 2022-08-19 00:00:00+05:30    0.500000
# 2023-09-22 00:00:00+05:30    0.500000
# 2024-09-20 00:00:00+05:30    0.500000
# 2025-09-10 00:00:00+05:30    0.500000
# Name: Dividends, dtype: float64

# %%
kitex.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2013-05-07 00:00:00+05:30   0.190476           0.0
# 2014-05-07 00:00:00+05:30   0.238095           0.0
# 2015-05-25 00:00:00+05:30   0.297619           0.0
# 2015-10-29 00:00:00+05:30   0.178571           0.0
# 2016-06-02 00:00:00+05:30   0.178571           0.0
# 2016-11-17 00:00:00+05:30   0.178571           0.0
# 2017-06-09 00:00:00+05:30   0.178571           0.0
# 2017-06-22 00:00:00+05:30   0.000000           1.4
# 2017-11-16 00:00:00+05:30   0.250000           0.0
# 2018-07-19 00:00:00+05:30   0.250000           0.0
# 2019-08-19 00:00:00+05:30   0.500000           0.0
# 2020-02-18 00:00:00+05:30   0.500000           0.0
# 2021-08-30 00:00:00+05:30   0.500000           0.0
# 2022-08-19 00:00:00+05:30   0.500000           0.0
# 2023-09-22 00:00:00+05:30   0.500000           0.0
# 2024-09-20 00:00:00+05:30   0.500000           0.0
# 2025-01-17 00:00:00+05:30   0.000000           3.0
# ...

# %%
kitex.splits
# Out:
# Date
# 2017-06-22 00:00:00+05:30    1.4
# 2025-01-17 00:00:00+05:30    3.0
# Name: Stock Splits, dtype: float64

# %%
kit
# Out:
#                           Date        Open        High         Low  \
# 0    2012-09-25 00:00:00+05:30   13.561352   14.468321   13.388596
# 1    2012-09-26 00:00:00+05:30   15.116156   15.116156   12.956706
# 2    2012-09-27 00:00:00+05:30   13.755703   13.777298   13.064678
# 3    2012-09-28 00:00:00+05:30   12.956706   13.345406   12.578802
# 4    2012-10-01 00:00:00+05:30   13.129459   13.906862   11.876979
# ...                        ...         ...         ...         ...
# 3204 2025-09-23 00:00:00+05:30  214.350006  217.500000  202.500000
# 3205 2025-09-24 00:00:00+05:30  206.850006  211.789993  205.089996
# 3206 2025-09-25 00:00:00+05:30  207.990005  210.199997  198.210007
# 3207 2025-09-26 00:00:00+05:30  201.800003  201.800003  189.610001
# 3208 2025-09-30 00:00:00+05:30  187.509995  190.419998  185.020004
#
#            Close   Volume  Dividends  Stock Splits
# 0      13.528960   250488        0.0           0.0
# 1      13.442582   154056        0.0           0.0
# ...

# %%
kitex.history(period='max', prepost = True, actions = True, start = '2025-01-01').plot(y='Close')
# Out:
# <Axes: xlabel='Date'>

# %%
k = kitex.history(period = 'max', prepost= True, actions = True, start = '2025-01-01')

# %%
k,.plot(x = "Date", y='Open', kind='hexbin')
