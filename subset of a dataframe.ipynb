# %%
csv_file = "/home/mintokuruvilla/Downloads/test.csv"

# %%
import pandas as pd
df = pd.read_csv(csv_file)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %% [markdown]
# ### Select age from the dataframe

# %%
df["Age"]
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **DataFrame.shape is an attribute that contains the number of rows and columns**

# %%
df["Age"].shape
# Out:
# (418,)

# %% [markdown]
# ### Selecting multiple columns from the data frame

# %%
df[["Age", "PassengerId"]]
# Out:
#       Age  PassengerId
# 0    34.5          892
# 1    47.0          893
# 2    62.0          894
# 3    27.0          895
# 4    22.0          896
# ..    ...          ...
# 413   NaN         1305
# 414  39.0         1306
# 415  38.5         1307
# 416   NaN         1308
# 417   NaN         1309
#
# [418 rows x 2 columns]

# %%
type(df[["Age", "PassengerId"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["Age", "PassengerId"]].shape
# Out:
# (418, 2)

# %% [markdown]
# ## FIltering specific rows in a dataframe

# %% [markdown]
# **Selecting passengers whose age is greater than 35**

# %%
df[df["Age"] > 50]
# Out:
#      PassengerId  Pclass                                               Name  \
# 2            894       2                          Myles, Mr. Thomas Francis
# 13           905       2                               Howard, Mr. Benjamin
# 20           912       1                             Rothschild, Mr. Martin
# 48           940       1    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 69           961       1                Fortune, Mrs. Mark (Mary McDougald)
# 77           969       1  Cornell, Mrs. Robert Clifford (Malvina Helen L...
# 81           973       1                                 Straus, Mr. Isidor
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 114         1006       1             Straus, Mrs. Isidor (Rosalie Ida Blun)
# 131         1023       1                          Gracie, Col. Archibald IV
# 142         1034       1                         Ryerson, Mr. Arthur Larned
# ...

# %%
df[df["Age"] < 35]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# 6            898       3                          Connolly, Miss. Kate
# ..           ...     ...                                           ...
# 403         1295       1                        Carrau, Mr. Jose Pedro
# 405         1297       2  Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                     Ware, Mr. William Jeffery
# 409         1301       3                     Peacock, Miss. Treasteall
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# ### isin()

# %%
df[df['SibSp'].isin([1,2])]
# Out:
#      PassengerId  Pclass                                             Name  \
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 7            899       2                     Caldwell, Mr. Albert Francis
# 9            901       3                          Davies, Mr. John Samuel
# 12           904       1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ..           ...     ...                                              ...
# 406         1298       2                        Ware, Mr. William Jeffery
# 407         1299       1                       Widener, Mr. George Dunton
# 409         1301       3                        Peacock, Miss. Treasteall
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df[(df['SibSp'] == 2) | (df['SibSp'] == 1)]
# Out:
#      PassengerId  Pclass                                             Name  \
# 1            893       3                 Wilkes, Mrs. James (Ellen Needs)
# 4            896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 7            899       2                     Caldwell, Mr. Albert Francis
# 9            901       3                          Davies, Mr. John Samuel
# 12           904       1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ..           ...     ...                                              ...
# 406         1298       2                        Ware, Mr. William Jeffery
# 407         1299       1                       Widener, Mr. George Dunton
# 409         1301       3                        Peacock, Miss. Treasteall
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
